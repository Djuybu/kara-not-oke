# %%
# %pip install "tensorflow<2.15"
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/284.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/284.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/284.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/284.2 MB 1.2 MB/s eta 0:03:57
#    ---------------------------------------- 0.5/284.2 MB 1.2 MB/s eta 0:03:57
#    ---------------------------------------- 0.5/284.2 MB 1.2 MB/s eta 0:03:57
#    ---------------------------------------- 0.8/284.2 MB 621.2 kB/s eta 0:07:37
#    ---------------------------------------- 0.8/284.2 MB 621.2 kB/s eta 0:07:37
#    ---------------------------------------- 1.0/284.2 MB 592.2 kB/s eta 0:07:59
#    ---------------------------------------- 1.0/284.2 MB 592.2 kB/s eta 0:07:59
#    ---------------------------------------- 1.0/284.2 MB 592.2 kB/s eta 0:07:59
# ...

# %%
import keras


model = keras.models.load_model(
    r"D:\sound_project\best_unet_vocal_kaggle.keras"
)
model.save("model.keras")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import tensorflow as tf
# ----> 2 import keras
#       5 model = keras.models.load_model(
#       6     r"D:\sound_project\best_unet_vocal_kaggle.keras"
#       7 )
#       8 model.save("model.keras")
#
# File d:\sound_project\python\Lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File d:\sound_project\python\Lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File d:\sound_project\python\Lib\site-packages\keras\__internal__\backend\__init__.py:3
# ...
